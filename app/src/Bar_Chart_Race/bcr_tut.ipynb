# %%
import pandas as pd
import openpyxl
import matplotlib as plt
import bar_chart_race as bcr

# %%
df = pd.read_excel("FML-Top20.xlsx")
df = df.fillna(0)
df.head()
# Out:
#       Season  AC Mailand  Arsenal London  AS Rom  Aston Villa  \
# 0  2018/2019         0.0             446   231.0          0.0
# 1  2017/2018       208.0             439   250.0          0.0
# 2  2016/2017         0.0             488     0.0          0.0
# 3  2015/2016       215.0             469   218.0          0.0
# 4  2014/2015       199.0             436   180.0          0.0
#
#    Atlético Madrid  Borussia Dortmund  FC Barcelona  FC Bayern München  \
# 0            368.0              377.0           841                660
# 1            304.0              317.0           690                629
# 2            273.0              333.0           648                588
# 3            229.0              284.0           620                592
# 4            187.0              281.0           561                474
#
#    FC Chelsea  ...  Olympique Marseille  Paris Saint-Germain  Real Madrid  \
# 0         513  ...                  0.0                636.0          757
# ...

# %%
df_test = bcr.load_dataset('covid19_tutorial')
bcr.bar_chart_race(df_test)
# Out:
# /Users/marcnordbruch/.pyenv/versions/3.8.7/envs/soccermaticsforpython/lib/python3.8/site-packages/bar_chart_race/_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# /Users/marcnordbruch/.pyenv/versions/3.8.7/envs/soccermaticsforpython/lib/python3.8/site-packages/bar_chart_race/_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# <video width="964" height="504" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
bcr.bar_chart_race(df)
# Out:
# /Users/marcnordbruch/.pyenv/versions/3.8.7/envs/soccermaticsforpython/lib/python3.8/site-packages/bar_chart_race/_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# /Users/marcnordbruch/.pyenv/versions/3.8.7/envs/soccermaticsforpython/lib/python3.8/site-packages/bar_chart_race/_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/.pyenv/versions/3.8.7/envs/soccermaticsforpython/lib/python3.8/site-packages/bar_chart_race/_make_chart.py in make_animation(self)
#     427             if self.html:
# --> 428                 ret_val = anim.to_html5_video()
#     429                 try:
#
# ...
